# %% [markdown]
# <a href="https://colab.research.google.com/github/devanshijain-12/Tiger_Analytics_Assignment/blob/main/Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

df = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/DS Internship - EDA - Data.xlsx")
# Out:
# Mounted at /content/drive

# %%
q1 = df.groupby("Year")["Sales"].sum()

q2 = df[df["Store Open"].astype(str).str.contains("1991")]["Store"].nunique()

q3 = df[df["Store Modification"].notna()]["Store"].nunique()

q4 = df["Sales"].corr(df["Total Sq Ft"])

q5 = df.groupby("Super Division")["Sales"].sum().sort_values(ascending=False).head(1)

q6 = df[df["Store Close"]=="No Close"]["Store"].nunique()

q7 = df.groupby("Super Division")["Total Sq Ft"].mean().sort_values(ascending=False).head(1)

q8 = df.groupby("State")["Sales"].mean().sort_values(ascending=False).head(3)

q9 = df.groupby("Month")["Sales"].mean().sort_values(ascending=False).head(1)

q10 = df.groupby(["Outlet Type","Store Close"]).size().unstack(fill_value=0)
